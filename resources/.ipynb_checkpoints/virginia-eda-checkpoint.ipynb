# %% [markdown]
# ## Virginia Counties
# #### Exploratory Data Analysis

# %% [markdown]
# https://www.kaggle.com/muonneutrino/us-census-demographic-data/download

# %%
import pandas as pd
import numpy as np

# %%
import plotly as py
import plotly.graph_objs as go
# from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# read in the dataset
counties = pd.read_csv('acs2017_county_data.csv')
counties.sample(3)
# Out:
#       CountyId    State          County  TotalPop    Men  Women  Hispanic  \
# 5         1011  Alabama  Bullock County     10478   5616   4862       0.3
# 1185     23017    Maine   Oxford County     57230  28290  28940       1.2
# 552      16003    Idaho    Adams County      3946   2021   1925       3.3
#
#       White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 5      21.6   75.6     1.0  ...   6.2          1.7         3.0         29.8
# 1185   95.6    0.3     0.3  ...   2.3          1.0         5.0         28.4
# 552    92.7    0.3     1.2  ...   4.4          1.8        10.9         24.1
#
#       Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 5         4290         81.4        13.6           5.0         0.0
# 1185     25524         77.8        12.1           9.8         0.2
# 552       1539         65.4        22.0          12.5         0.0
#
#       Unemployment
# 5             12.1
# 1185           6.3
# 552            8.7
#
# [3 rows x 37 columns]

# %%
# restrict to Virginia
va = counties.loc[counties['State']=='Virginia']
print(counties.shape)
print(va.shape)
# Out:
# (3220, 37)
# (133, 37)

# %%
# show a list of variables
va.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 2820 to 2952
# Data columns (total 37 columns):
# CountyId            133 non-null int64
# State               133 non-null object
# County              133 non-null object
# TotalPop            133 non-null int64
# Men                 133 non-null int64
# Women               133 non-null int64
# Hispanic            133 non-null float64
# White               133 non-null float64
# Black               133 non-null float64
# Native              133 non-null float64
# Asian               133 non-null float64
# Pacific             133 non-null float64
# VotingAgeCitizen    133 non-null int64
# Income              133 non-null int64
# IncomeErr           133 non-null int64
# IncomePerCap        133 non-null int64
# IncomePerCapErr     133 non-null int64
# Poverty             133 non-null float64
# ChildPoverty        133 non-null float64
# Professional        133 non-null float64
# Service             133 non-null float64
# Office              133 non-null float64
# Construction        133 non-null float64
# Production          133 non-null float64
# Drive               133 non-null float64
# Carpool             133 non-null float64
# Transit             133 non-null float64
# Walk                133 non-null float64
# OtherTransp         133 non-null float64
# WorkAtHome          133 non-null float64
# MeanCommute         133 non-null float64
# Employed            133 non-null int64
# PrivateWork         133 non-null float64
# PublicWork          133 non-null float64
# SelfEmployed        133 non-null float64
# FamilyWork          133 non-null float64
# Unemployment        133 non-null float64
# dtypes: float64(25), int64(10), object(2)
# memory usage: 39.5+ KB

# %% [markdown]
# #### Data Dictionary
# | Varname | Data |
# |:---:|:---|
# | CensusTract | Census tract ID |
# | State | State, DC, or Puerto Rico |
# |County | County or county equivalent |
# | Total | PopTotal population |
# | Men | Number of men |
# |Women|Number of women |
# |Hispanic|% of population that is Hispanic/Latino|
# |White|% of population that is white|
# |Black|% of population that is black|
# |Native|% of population that is Native American or Native Alaskan|
# |Asian|% of population that is Asian|
# |Pacific|% of population that is Native Hawaiian or Pacific Islander|
# |Citizen|Number of citizens|
# |Income|Median household income |
# |IncomeErr|Median household income error|
# |IncomePerCap|Income per capita |
# |IncomePerCapErr|Income per capita error |
# |Poverty|% under poverty level|
# |ChildPoverty|% of children under poverty level|
# |Professional|% employed in management, business, science, and arts|
# |Service|% employed in service jobs|
# |Office|% employed in sales and office jobs|
# |Construction|% employed in natural resources, construction, and maintenance|
# |Production|% employed in production, transportation, and material movement|
# |Drive|% commuting alone in a car, van, or truck|
# |Carpool|% carpooling in a car, van, or truck|
# |Transit|% commuting on public transportation|
# |Walk|% walking to work|
# |OtherTransp|% commuting via other means|
# |WorkAtHome|% working at home|
# |MeanCommute|Mean commute time (minutes)|
# |Employed|Number of employed (16+)|
# |PrivateWork|% employed in private industry|
# |PublicWork|% employed in public jobs|
# |SelfEmployed|% self-employed|
# |FamilyWork|% in unpaid family work|
# |Unemployment|Unemployment rate (%)|

# %% [markdown]
# ### Rural or Urban?
# https://www.ers.usda.gov/data-products/rural-urban-continuum-codes/

# %%
# get the USDA county rural-urban codes
usda=pd.read_excel('ruralurbancodes2013.xls')
usda.sample(3)
# Out:
#        FIPS State           County_Name  Population_2010  RUCC_2013  \
# 3206  72125    PR  San German Municipio            35527          3
# 2182  40103    OK          Noble County            11561          6
# 1945  37111    NC       McDowell County            44996          6
#
#                                             Description
# 3206  Metro - Counties in metro areas of fewer than ...
# 2182  Nonmetro - Urban population of 2,500 to 19,999...
# 1945  Nonmetro - Urban population of 2,500 to 19,999...

# %%
# what are the codes?
usda.groupby('RUCC_2013')[['RUCC_2013','Description']].max()
# Out:
#            RUCC_2013                                        Description
# RUCC_2013
# 1                  1  Metro - Counties in metro areas of 1 million p...
# 2                  2  Metro - Counties in metro areas of 250,000 to ...
# 3                  3  Metro - Counties in metro areas of fewer than ...
# 4                  4  Nonmetro - Urban population of 20,000 or more,...
# 5                  5  Nonmetro - Urban population of 20,000 or more,...
# 6                  6  Nonmetro - Urban population of 2,500 to 19,999...
# 7                  7  Nonmetro - Urban population of 2,500 to 19,999...
# 8                  8  Nonmetro - Completely rural or less than 2,500...
# 9                  9  Nonmetro - Completely rural or less than 2,500...

# %%
# merge with VA data
va2=pd.merge(va, usda, left_on='CountyId', right_on='FIPS', how='left')
print(va.shape)
print(va2.shape)
# Out:
# (133, 37)
# (133, 43)

# %%
# what are the counts?
va2['RUCC_2013'].value_counts()
# Out:
# 1    48
# 6    20
# 3    18
# 8    14
# 2    14
# 9     7
# 7     7
# 4     4
# 5     1
# Name: RUCC_2013, dtype: int64

# %%
# simplify the rural-urban indicator
va2['metro']=va2['RUCC_2013'].map({1:'urban', 
                                   2:'suburban',
                                   3:'suburban',
                                   4:'town',
                                   5:'town',
                                   6:'town',
                                   7:'rural',
                                   8:'rural',
                                   9:'rural'})
# sort as categories
va2['metro'] = pd.Categorical(va2['metro'], ['urban', 'suburban', 'town', 'rural'])
va2['metro'].value_counts()
# Out:
# urban       48
# suburban    32
# rural       28
# town        25
# Name: metro, dtype: int64

# %%
# are there differences in commuting and transit patterns?
va2.groupby('metro')[['MeanCommute', 'Drive','Carpool','Transit']].mean().sort_index()
# Out:
#           MeanCommute    Drive    Carpool   Transit
# metro
# urban       30.108333  78.6750   9.166667  3.295833
# suburban    25.137500  79.9375  10.062500  1.065625
# town        26.156000  81.9000   8.636000  0.484000
# rural       27.596429  82.5000   9.092857  0.517857

# %%
# are there differences in income and poverty?
va2.groupby('metro')[['Income', 'IncomePerCap','Unemployment', 'Poverty']].mean().sort_index()
# Out:
#                Income  IncomePerCap  Unemployment    Poverty
# metro
# urban     73025.93750  35221.312500      5.754167  10.966667
# suburban  52126.46875  27473.312500      5.115625  14.725000
# town      45021.20000  23797.920000      7.112000  17.184000
# rural     42324.75000  24306.392857      6.600000  17.275000

# %%
# are there differences in race-ethnicity?
va2.groupby('metro')[['White','Black','Hispanic','Asian','Native']].mean().sort_index()
# Out:
#               White      Black  Hispanic     Asian    Native
# metro
# urban     62.535417  21.933333  8.056250  3.812500  0.381250
# suburban  82.109375   9.875000  4.115625  1.565625  0.181250
# town      67.700000  25.916000  3.224000  0.988000  0.196000
# rural     79.010714  15.364286  2.967857  0.589286  0.214286

# %%
# are there differences in industry?
va2.groupby('metro')[['Professional','Service','Office','Construction','Production']].mean().sort_index()
# Out:
#           Professional    Service     Office  Construction  Production
# metro
# urban        40.116667  17.116667  22.879167      9.977083    9.918750
# suburban     35.015625  18.606250  23.021875      9.496875   13.868750
# town         29.144000  19.780000  23.336000     11.016000   16.712000
# rural        28.371429  19.785714  22.517857     13.371429   15.953571

# %%
# Differences in sector?
va2.groupby('metro')[['PrivateWork','PublicWork']].mean().sort_index()
# Out:
#           PrivateWork  PublicWork
# metro
# urban       73.933333   20.839583
# suburban    76.600000   17.709375
# town        74.992000   19.352000
# rural       74.010714   19.189286

# %%
# display all counties
import plotly.figure_factory as ff

values = va2['Income']

fig = ff.create_choropleth(fips=va2['FIPS'], 
                           values=values, 
                           scope=['VA'], 
                           county_outline={'color': 'rgb(255,255,255)', 'width': 0.5})
iplot(fig)
# Out:
# <div>
#
#
#             <div id="8602790b-a577-410c-99b9-f164cf3cd79b" class="plotly-graph-div" style="height:450px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8602790b-a577-410c-99b9-f164cf3cd79b")) {
#                     Plotly.newPlot(
#                         '8602790b-a577-410c-99b9-f164cf3cd79b',
#                         [{"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "26971", "type": "scatter", "x": [-82.66293399999999, -82.633893, -82.58888999999999, -82.61513699999999, -82.66293399999999, null], "y": [36.921217999999996, 36.952629, 36.951181999999996, 36.905251, 36.921217999999996, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "27426", "type": "scatter", "x": [-77.56284099999999, -77.514877, -77.506716, -77.548203, -77.56284099999999, null], "y": [36.703382999999995, 36.720565, 36.690124, 36.671898999999996, 36.703382999999995, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "29916", "type": "scatter", "x": [-82.55383499999999, -82.293166, -82.13681299999999, -82.362229, -82.479298, -82.54621999999999, -82.55383499999999, null], "y": [37.202841, 37.306022, 37.050346999999995, 36.955855, 37.02445, 37.124981999999996, 37.202841, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30828", "type": "scatter", "x": [-82.3147177936376, -81.968012, -81.92673599999999, -81.99607499999999, -81.935621, -81.928497, -81.849949, -81.76021999999999, -81.7392766866866, -81.914273, -82.007716, -82.041688, -82.147284, -82.25052199999999, -82.3147177936376, null], "y": [37.2959066788752, 37.538035, 37.51304, 37.471526, 37.438396999999995, 37.360645, 37.285227, 37.275254, 37.2388369743647, 37.130722, 37.119870999999996, 37.048500000000004, 37.040507999999996, 37.273134999999996, 37.2959066788752, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "31311", "type": "scatter", "x": [-80.94957699999999, -80.91797299999999, -80.877274, -80.92107299999999, -80.94957699999999, null], "y": [36.663019999999996, 36.694002999999995, 36.692215, 36.625549, 36.663019999999996, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "32048", "type": "scatter", "x": [-80.936572, -80.937693, -80.93085099999999, -80.938375, -80.936572, null, -81.6469, -81.54733499999999, -81.529336, -81.08851, -81.042406, -80.93827499999999, -80.931147, -80.91417299999999, -80.8379544979468, -81.67753499999999, -81.6469, null], "y": [36.675429, 36.678134, 36.669879, 36.672016, 36.675429, null, 36.611917999999996, 36.656918, 36.706817, 36.767421999999996, 36.806422, 36.678837, 36.625268, 36.650245999999996, 36.5591308803947, 36.588117, 36.611917999999996, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "32590", "type": "scatter", "x": [-83.675395, -83.529612, -83.136395, -83.07258999999999, -82.8783615743726, -82.77130799999999, -82.828071, -82.947535, -82.9851235492625, -83.675395, null], "y": [36.600784, 36.666184, 36.743088, 36.854589, 36.8932176332157, 36.79988, 36.729273, 36.67584, 36.5937302148783, 36.600784, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "33545", "type": "scatter", "x": [-79.904077, -79.87476, -79.83735899999999, -79.827359, -79.904077, null], "y": [36.684127, 36.715337, 36.704136999999996, 36.647636999999996, 36.684127, null]}, {"fill": "toself", "fillcolor": "rgb(72, 24, 106)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "33672", "type": "scatter", "x": [-79.38264199999999, -79.380274, -79.328768, -79.34878499999999, -79.38264199999999, null], "y": [37.70 ...
